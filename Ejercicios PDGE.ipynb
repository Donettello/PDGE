# %% [markdown]
# # Ejercicios Procesamiento de Datos a Gran Escala

# %% [markdown]
# Resolución de ejercicios y explicación.

# %% [markdown]
# ## Hadoop y Spark

# %% [markdown]
# ## GPGPU

# %% [markdown]
# ## Computación cuántica
